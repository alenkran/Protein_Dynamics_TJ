# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# Import the ISOMAP results
im_coors = np.load('C:\Users\minch_000\Documents\TJ_data\isomap_out\isomap_coordinates_40_2_100_1.0.dat')
iso_cluster_labels = np.load('C:\Users\minch_000\Documents\TJ_data\isomap_out\isomap_clustering_labels_30_45_97.dat')

# Import diffusion map results
se_coors= np.load('C:\Users\minch_000\Documents\TJ_data\spec_embed_out\spec_embed_coordinates_20_35_97.dat')
se_cluster_labels = np.load('C:\Users\minch_000\Documents\TJ_data\spec_embed_out\spec_embed_clustering_labels_20_35_97.dat')

# Import the MSM builder results
msm_cluster_labels = np.load('C:\Users\minch_000\Documents\TJ_data\msm_out\msm_clustering_labels.dat')

# %%
num_frames = im_coors.shape[0]

# Plot
plt.scatter(im_coors[:,0], im_coors[:,1], c=msm_cluster_labels[indices])
plt.xlabel('rd1')
plt.ylabel('rd2')
plt.title('ISOMAP')
plt.show()

# %%
num_frames = im_coors.shape[0]

# Plot
plt.scatter(se_coors[:,2], se_coors[:,11], c=msm_cluster_labels[indices])
plt.xlabel('rd1')
plt.ylabel('rd2')
plt.title('Spectral Embedding')
plt.show()

# %%
se_coors.shape
# Out:
# (28000L, 35L)

# %%
# Density
plt.hexbin(im_coors[indices,0], im_coors[indices,1], bins='log', mincnt=1, cmap='viridis')
plt.show()
