# %%
#get data
import random
random.seed(0)

from msmbuilder.example_datasets import FsPeptide
fs_peptide = FsPeptide()
fs_peptide.cache()

# %%
# Load data from sherlock
import numpy as np
left_eigenvector = np.load('./sherlock_data/lv_100_100.dat') #49,21

# %%
import tempfile
import os
os.chdir(tempfile.mkdtemp())

# %%
data_dir = 'C:\Users\Christian\Documents\GitHub\Protein_Dynamics_TJ\MSM_Builder_Test\\trajectories'

# %%
from msmbuilder.dataset import dataset
xyz = dataset(data_dir + "/*.xtc",
              topology=fs_peptide.data_dir + '/fs-peptide.pdb',
              stride=1)

print("{} trajectories".format(len(xyz)))
# msmbuilder does not keep track of units! You must keep track of your
# data's timestep
to_ns = 0.5
print("with length {} ns".format(set(len(x)*to_ns for x in xyz)))
# Out:
# C:\Anaconda2\lib\site-packages\mdtraj\formats\pdb\pdbfile.py:196: UserWarning: Unlikely unit cell vectors detected in PDB file likely resulting from a dummy CRYST1 record. Discarding unit cell vectors.
#   warnings.warn('Unlikely unit cell vectors detected in PDB file likely '
# 10000 trajectories
# with length set([50.0]) ns

# %%
#featurization

from msmbuilder.featurizer import DihedralFeaturizer
featurizer = DihedralFeaturizer(types=['phi', 'psi'])
diheds = xyz.fit_transform_with(featurizer, 'diheds/', fmt='dir-npy')

print(xyz[0].xyz.shape)
print(diheds[0].shape)
# Out:
# (100L, 264L, 3L)
# (100L, 84L)

# %%
#tICA

from msmbuilder.decomposition import tICA
random.seed(0)
tica_model = tICA(lag_time=2, n_components=4)
# fit and transform can be done in seperate steps:
tica_model = diheds.fit_with(tica_model)
tica_trajs = diheds.transform_with(tica_model, 'ticas/', fmt='dir-npy')

print(diheds[0].shape)
print(tica_trajs[0].shape)
# Out:
# (100L, 84L)
# (100L, 4L)

# %%
#histogram

# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
txx = np.concatenate(tica_trajs)
plt.hexbin(txx[:,0], txx[:,1], bins='log', mincnt=1, cmap='viridis')

# %%
#clustering
from msmbuilder.cluster import MiniBatchKMeans
random.seed(0)
clusterer = MiniBatchKMeans(n_clusters=97)
clustered_trajs = tica_trajs.fit_transform_with(
    clusterer, 'kmeans/', fmt='dir-npy'
)

print(tica_trajs[0].shape)
print(clustered_trajs[0].shape)
# Out:
# (100L, 4L)
# (100L,)

# %%
#show cluster

plt.hexbin(txx[:,0], txx[:,1], bins='log', mincnt=1, cmap='viridis')
plt.scatter(clusterer.cluster_centers_[:,0],
            clusterer.cluster_centers_[:,1], 
            s=100, c='w')

# %%
#msm builder

from msmbuilder.msm import MarkovStateModel
from msmbuilder.utils import dump
msm = MarkovStateModel(lag_time=2, n_timescales=20,  ergodic_cutoff='off')
msm.fit(clustered_trajs)
# Out:
# C:\Anaconda2\lib\site-packages\msmbuilder\msm\msm.py:183: UserWarning: reversible_type='mle' and ergodic_cutoff <= 0 are not generally compatible
#   warnings.warn("reversible_type='mle' and ergodic_cutoff <= 0 "
# MarkovStateModel(ergodic_cutoff='off', lag_time=2, n_timescales=20,
#          prior_counts=0, reversible_type='mle', sliding_window=True,
#          verbose=True)

# %%
plt.hexbin(txx[:, 0], txx[:, 1], bins='log', mincnt=1, cmap="bone_r")
plt.scatter(clusterer.cluster_centers_[msm.state_labels_, 0],
            clusterer.cluster_centers_[msm.state_labels_, 1],
            s=1e4 * msm.populations_,       # size by population
            c=msm.left_eigenvectors_[:, 1], # color by eigenvector
            cmap="coolwarm") 
plt.colorbar(label='First dynamical eigenvector')
plt.xlabel('tIC 1')
plt.ylabel('tIC 2')
#plt.tight_layout()

# %%
from msmbuilder.tpt import mfpts 
mfpt_matrix = mfpts(msm)
print len(mfpt_matrix)
# Out:
# 97

# %%
plt.subplots(figsize=(3,5))
plt.hlines(msm.timescales_ * to_ns, 0, 1, color='b')
plt.yscale('log')
plt.xticks([])
plt.ylabel("Timescales / ns", fontsize=18)
plt.tight_layout()

# %%
#macrostate model

from msmbuilder.lumping import PCCAPlus
pcca = PCCAPlus.from_msm(msm, n_macrostates=4)
macro_trajs = pcca.transform(clustered_trajs)
# Out:
# Optimization terminated successfully.
#          Current function value: -3.996009
#          Iterations: 11
#          Function evaluations: 111

# %%
plt.hexbin(txx[:, 0], txx[:, 1], bins='log', mincnt=1, cmap="bone_r")
plt.scatter(clusterer.cluster_centers_[msm.state_labels_, 0],
            clusterer.cluster_centers_[msm.state_labels_, 1],
            s=50,
            c=pcca.microstate_mapping_,
)
plt.xlabel('tIC 1')
plt.ylabel('tIC 2')

# %%
print msm.eigenvalues_
print msm.left_eigenvectors_[:,0].shape
print str(len(xyz[0].xyz))
i = 0
print np.linalg.norm(lv[:,i])
print np.dot(lv[:,i], np.transpose(lv[:,i]))
# Out:
# [ 1.          0.99970206  0.99916294  0.9981708   0.9978564   0.99779415
#   0.99763052  0.99710107  0.9952977   0.99448407  0.99446181  0.99305921
#   0.99276403  0.99044697  0.98847642  0.98708312  0.98667896  0.98554881
#   0.98471293  0.9824157   0.98109465]
# (97L,)
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-48-fd48d2eeeeab> in <module>()
#       1 print msm.eigenvalues_
#       2 print msm.left_eigenvectors_[:,0].shape
# ----> 3 print str(len(xyz[0].xyz))
#       4 lv = msm.left_eigenvectors_
#       5 i = 0
#
# C:\Anaconda2\lib\site-packages\msmbuilder\dataset.pyc in __getitem__(self, i)
#     246             assert i.start is None and i.step is None and i.stop is None, err
#     247             return [self.get(i) for i in self.keys()]
# --> 248         return self.get(i)
#     249
#     250     def __setitem__(self, i, x):
#
# C:\Anaconda2\lib\site-packages\msmbuilder\dataset.pyc in get(self, i)
#     455         else:
#     456             t = md.load(self.filename(i), stride=self.stride,
# --> 457                         atom_indices=self.atom_indices, top=self._topology)
#     458         return t
#     459
#
# C:\Anaconda2\lib\site-packages\mdtraj\core\trajectory.pyc in load(filename_or_filenames, discard_overlapping_frames, **kwargs)
#     415
#     416     if loader.__name__ not in ['load_dtr']:
# --> 417         _assert_files_exist(filename_or_filenames)
#     418     else:
#     419         _assert_files_or_dirs_exist(filename_or_filenames)
#
# C:\Anaconda2\lib\site-packages\mdtraj\core\trajectory.pyc in _assert_files_exist(filenames)
#      94     for fn in filenames:
#      95         if not (os.path.exists(fn) and os.path.isfile(fn)):
# ---> 96             raise IOError('No such file: %s' % fn)
#      97
#      98
#
# IOError: No such file: C:\Users\Christian\Documents\GitHub\Protein_Dynamics_TJ\MSM_Builder_Test\trajectories\1.xtc

# %%
lv_orig = np.load('C:\Users\Christian\Documents\GitHub\Protein_Dynamics_TJ\MSM_Builder_Test\Sherlock_Data\\lv_fs_original_stride_10.dat')
lv = msm.left_eigenvectors_

idx_sort = msm.populations_.argsort()[-len(msm.populations_):][::-1]
lv = lv[idx_sort,:]
a = lv
b = lv_orig #already sorted

n = 0
m = 98
for i in range(len(a[0,:])):
    denom = np.linalg.norm(a[n:m,i])*np.linalg.norm(b[n:m,i])
    theta = np.dot(a[n:m,i],b[n:m,i])/denom
    print theta
# Out:
# 0.834477368737
# 0.182308342697
# -0.0228415994709
# -0.055222894923
# -0.0687226808267
# 0.123722836781
# 0.0118932539572
# 0.130011958063
# 0.00326227694392
# -0.272148429208
# 0.0948099194543
# 0.0396457425024
# 0.101975628807
# -0.0960157743006
# -0.106864724644
# -0.0201515336288
# 0.0471352453789
# -0.0967623824522
# -0.0540761404068
# -0.137664795393
# -0.0291361001767

# %%
print np.argmax(np.array(msm.populations_))
# Out:
# 45
